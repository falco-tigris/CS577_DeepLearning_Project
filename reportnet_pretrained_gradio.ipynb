# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d raddar/chest-xrays-indiana-university
# Out:
# Downloading chest-xrays-indiana-university.zip to /content
# 100% 13.2G/13.2G [07:40<00:00, 31.4MB/s]
# 100% 13.2G/13.2G [07:40<00:00, 30.7MB/s]

# %%
# !unzip /content/chest-xrays-indiana-university.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images/images_normalized/219_IM-0799-1001.dcm.png
#   inflating: images/images_normalized/219_IM-0799-2001.dcm.png
#   inflating: images/images_normalized/21_IM-0729-1001-0001.dcm.png
#   inflating: images/images_normalized/21_IM-0729-1001-0002.dcm.png
#   inflating: images/images_normalized/2200_IM-0811-1001.dcm.png
#   inflating: images/images_normalized/2200_IM-0811-2001.dcm.png
#   inflating: images/images_normalized/2201_IM-0811-1002.dcm.png
#   inflating: images/images_normalized/2202_IM-0811-1001.dcm.png
#   inflating: images/images_normalized/2202_IM-0811-1002.dcm.png
#   inflating: images/images_normalized/2203_IM-0812-1001.dcm.png
#   inflating: images/images_normalized/2203_IM-0812-2001.dcm.png
#   inflating: images/images_normalized/2204_IM-0813-1001.dcm.png
#   inflating: images/images_normalized/2204_IM-0813-1002.dcm.png
#   inflating: images/images_normalized/2205_IM-0814-1001.dcm.png
#   inflating: images/images_normalized/2206_IM-0815-1001.dcm.png
#   inflating: images/images_normalized/2206_IM-0815-2001.dcm.png
#   inflating: images/images_normalized/2207_IM-0815-1001.dcm.png
#   inflating: images/images_normalized/2207_IM-0815-2001.dcm.png
#   inflating: images/images_normalized/2208_IM-0815-1001.dcm.png
#   inflating: images/images_normalized/2208_IM-0815-1002.dcm.png
#   inflating: images/images_normalized/2209_IM-0816-1001.dcm.png
#   inflating: images/images_normalized/2209_IM-0816-2001.dcm.png
#   inflating: images/images_normalized/220_IM-0811-1001.dcm.png
#   inflating: images/images_normalized/220_IM-0811-1002.dcm.png
#   inflating: images/images_normalized/220_IM-0811-1003.dcm.png
#   inflating: images/images_normalized/2210_IM-0817-1001.dcm.png
#   inflating: images/images_normalized/2210_IM-0817-2001.dcm.png
#   inflating: images/images_normalized/2211_IM-0818-1001.dcm.png
#   inflating: images/images_normalized/2211_IM-0818-2001.dcm.png
#   inflating: images/images_normalized/2212_IM-0819-1001.dcm.png
#   inflating: images/images_normalized/2212_IM-0819-2001.dcm.png
#   inflating: images/images_normalized/2213_IM-0819-1001.dcm.png
#   inflating: images/images_normalized/2213_IM-0819-3001.dcm.png
#   inflating: images/images_normalized/2214_IM-0819-1002.dcm.png
#   inflating: images/images_normalized/2215_IM-0820-1001.dcm.png
#   inflating: images/images_normalized/2215_IM-0820-2001.dcm.png
#   inflating: images/images_normalized/2216_IM-0821-85075001.dcm.png
#   inflating: images/images_normalized/2216_IM-0821-85075002.dcm.png
#   inflating: images/images_normalized/2217_IM-0822-0001-0001.dcm.png
#   inflating: images/images_normalized/2217_IM-0822-0001-0002.dcm.png
#   inflating: images/images_normalized/2218_IM-0823-1001.dcm.png
#   inflating: images/images_normalized/2218_IM-0823-2001.dcm.png
#   inflating: images/images_normalized/2218_IM-0823-3001.dcm.png
#   inflating: images/images_normalized/2219_IM-0823-1001.dcm.png
#   inflating: images/images_normalized/2219_IM-0823-2001.dcm.png
#   inflating: images/images_normalized/221_IM-0817-1001.dcm.png
#   inflating: images/images_normalized/221_IM-0817-2001.dcm.png
#   inflating: images/images_normalized/2220_IM-0824-4004.dcm.png
#   inflating: images/images_normalized/2221_IM-0825-1001.dcm.png
#   inflating: images/images_normalized/2221_IM-0825-2001.dcm.png
#   inflating: images/images_normalized/2222_IM-0826-1001.dcm.png
#   inflating: images/images_normalized/2222_IM-0826-2001.dcm.png
#   inflating: images/images_normalized/2223_IM-0827-1001.dcm.png
#   inflating: images/images_normalized/2223_IM-0827-2001.dcm.png
#   inflating: images/images_normalized/2224_IM-0828-1001.dcm.png
#   inflating: images/images_normalized/2224_IM-0828-2001.dcm.png
#   inflating: images/images_normalized/2225_IM-0829-3001.dcm.png
#   inflating: images/images_normalized/2225_IM-0829-4001.dcm.png
#   inflating: images/images_normalized/2226_IM-0830-12001.dcm.png
#   inflating: images/images_normalized/2226_IM-0830-13001.dcm.png
#   inflating: images/images_normalized/2227_IM-0831-2001.dcm.png
#   inflating: images/images_normalized/2228_IM-0831-1001.dcm.png
#   inflating: images/images_normalized/2228_IM-0831-1002.dcm.png
#   inflating: images/images_normalized/2229_IM-0831-1001.dcm.png
#   inflating: images/images_normalized/2229_IM-0831-1002.dcm.png
#   inflating: images/images_normalized/222_IM-0823-1001.dcm.png
#   inflating: images/images_normalized/222_IM-0823-3003.dcm.png
#   inflating: images/images_normalized/2230_IM-0831-1001.dcm.png
#   inflating: images/images_normalized/2230_IM-0831-2001.dcm.png
#   inflating: images/images_normalized/2231_IM-0831-1001.dcm.png
#   inflating: images/images_normalized/2231_IM-0831-2001.dcm.png
#   inflating: images/images_normalized/2231_IM-0831-3001.dcm.png
#   inflating: images/images_normalized/2232_IM-0832-1001.dcm.png
#   inflating: images/images_normalized/2232_IM-0832-2001.dcm.png
#   inflating: images/images_normalized/2233_IM-0832-1001.dcm.png
#   inflating: images/images_normalized/2233_IM-0832-2001.dcm.png
#   inflating: images/images_normalized/2234_IM-0833-1001.dcm.png
#   inflating: images/images_normalized/2234_IM-0833-1002.dcm.png
#   inflating: images/images_normalized/2235_IM-0833-1001.dcm.png
#   inflating: images/images_normalized/2235_IM-0833-2001.dcm.png
#   inflating: images/images_normalized/2236_IM-0833-1001.dcm.png
#   inflating: images/images_normalized/2236_IM-0833-2002.dcm.png
#   inflating: images/images_normalized/2237_IM-0834-2002.dcm.png
#   inflating: images/images_normalized/2237_IM-0834-3003.dcm.png
#   inflating: images/images_normalized/2238_IM-0835-1001.dcm.png
#   inflating: images/images_normalized/2238_IM-0835-2001.dcm.png
#   inflating: images/images_normalized/2239_IM-0836-1001.dcm.png
#   inflating: images/images_normalized/2239_IM-0836-2001.dcm.png
#   inflating: images/images_normalized/223_IM-0831-1001.dcm.png
#   inflating: images/images_normalized/223_IM-0831-2001.dcm.png
#   inflating: images/images_normalized/2240_IM-0838-1001.dcm.png
#   inflating: images/images_normalized/2240_IM-0838-1002.dcm.png
#   inflating: images/images_normalized/2241_IM-0839-28001.dcm.png
#   inflating: images/images_normalized/2242_IM-0840-1001.dcm.png
#   inflating: images/images_normalized/2242_IM-0840-2001.dcm.png
#   inflating: images/images_normalized/2243_IM-0840-1001.dcm.png
#   inflating: images/images_normalized/2243_IM-0840-2001.dcm.png
#   inflating: images/images_normalized/2243_IM-0840-3001.dcm.png
#   inflating: images/images_normalized/2243_IM-0840-4001.dcm.png
#   inflating: images/images_normalized/2244_IM-0841-2002.dcm.png
#   inflating: images/images_normalized/2244_IM-0841-3003.dcm.png
#   inflating: images/images_normalized/2245_IM-0842-1001.dcm.png
#   inflating: images/images_normalized/2245_IM-0842-2001.dcm.png
#   inflating: images/images_normalized/2246_IM-0843-1001.dcm.png
#   inflating: images/images_normalized/2246_IM-0843-2001.dcm.png
#   inflating: images/images_normalized/2247_IM-0844-1001.dcm.png
#   inflating: images/images_normalized/2247_IM-0844-2001.dcm.png
#   inflating: images/images_normalized/2248_IM-0844-1001.dcm.png
#   inflating: images/images_normalized/2248_IM-0844-1002.dcm.png
#   inflating: images/images_normalized/2249_IM-0844-1001.dcm.png
#   inflating: images/images_normalized/2249_IM-0844-2001.dcm.png
#   inflating: images/images_normalized/224_IM-0837-1001.dcm.png
#   inflating: images/images_normalized/224_IM-0837-2001.dcm.png
#   inflating: images/images_normalized/2250_IM-0844-1001.dcm.png
#   inflating: images/images_normalized/2251_IM-0844-1001.dcm.png
#   inflating: images/images_normalized/2252_IM-0844-1001.dcm.png
#   inflating: images/images_normalized/2252_IM-0844-1002.dcm.png
#   inflating: images/images_normalized/2253_IM-0845-1002001.dcm.png
#   inflating: images/images_normalized/2253_IM-0845-1003002.dcm.png
#   inflating: images/images_normalized/2254_IM-0846-1001.dcm.png
#   inflating: images/images_normalized/2255_IM-0847-3001.dcm.png
#   inflating: images/images_normalized/2255_IM-0847-4001.dcm.png
#   inflating: images/images_normalized/2256_IM-0848-1001.dcm.png
#   inflating: images/images_normalized/2256_IM-0848-3001.dcm.png
#   inflating: images/images_normalized/2256_IM-0848-4001.dcm.png
#   inflating: images/images_normalized/2257_IM-0849-1001.dcm.png
#   inflating: images/images_normalized/2257_IM-0849-2001.dcm.png
#   inflating: images/images_normalized/2258_IM-0849-1001.dcm.png
#   inflating: images/images_normalized/2258_IM-0849-2001.dcm.png
#   inflating: images/images_normalized/2259_IM-0850-1001.dcm.png
#   inflating: images/images_normalized/2259_IM-0850-2001.dcm.png
#   inflating: images/images_normalized/225_IM-0844-1001.dcm.png
#   inflating: images/images_normalized/225_IM-0844-2001.dcm.png
#   inflating: images/images_normalized/2260_IM-0852-1001.dcm.png
#   inflating: images/images_normalized/2260_IM-0852-2001.dcm.png
#   inflating: images/images_normalized/2261_IM-0852-1001.dcm.png
#   inflating: images/images_normalized/2261_IM-0852-2001.dcm.png
#   inflating: images/images_normalized/2262_IM-0852-1001.dcm.png
#   inflating: images/images_normalized/2262_IM-0852-2001.dcm.png
#   inflating: images/images_normalized/2263_IM-0853-1001.dcm.png
#   inflating: images/images_normalized/2263_IM-0853-4001.dcm.png
#   inflating: images/images_normalized/2264_IM-0854-1001.dcm.png
#   inflating: images/images_normalized/2264_IM-0854-2001.dcm.png
#   inflating: images/images_normalized/2265_IM-0855-1001.dcm.png
#   inflating: images/images_normalized/2265_IM-0855-2001.dcm.png
#   inflating: images/images_normalized/2266_IM-0855-1001.dcm.png
#   inflating: images/images_normalized/2266_IM-0855-2001.dcm.png
#   inflating: images/images_normalized/2266_IM-0855-3001.dcm.png
#   inflating: images/images_normalized/2267_IM-0856-1001.dcm.png
#   inflating: images/images_normalized/2267_IM-0856-2001.dcm.png
#   inflating: images/images_normalized/2268_IM-0857-1001.dcm.png
#   inflating: images/images_normalized/2268_IM-0857-2001.dcm.png
#   inflating: images/images_normalized/2269_IM-0858-1001.dcm.png
#   inflating: images/images_normalized/2269_IM-0858-2001.dcm.png
#   inflating: images/images_normalized/226_IM-0851-1001.dcm.png
#   inflating: images/images_normalized/226_IM-0851-2001.dcm.png
#   inflating: images/images_normalized/2270_IM-0859-1001.dcm.png
#   inflating: images/images_normalized/2270_IM-0859-2001.dcm.png
#   inflating: images/images_normalized/2271_IM-0860-1001.dcm.png
#   inflating: images/images_normalized/2272_IM-0861-1001.dcm.png
#   inflating: images/images_normalized/2272_IM-0861-2001.dcm.png
#   inflating: images/images_normalized/2273_IM-0861-1001.dcm.png
#   inflating: images/images_normalized/2273_IM-0861-1002.dcm.png
#   inflating: images/images_normalized/2274_IM-0861-1001.dcm.png
#   inflating: images/images_normalized/2275_IM-0862-1001.dcm.png
#   inflating: images/images_normalized/2275_IM-0862-2001.dcm.png
#   inflating: images/images_normalized/2276_IM-0863-1001-0001.dcm.png
#   inflating: images/images_normalized/2276_IM-0863-1001-0002.dcm.png
#   inflating: images/images_normalized/2277_IM-0864-1001.dcm.png
#   inflating: images/images_normalized/2277_IM-0864-2001.dcm.png
#   inflating: images/images_normalized/2278_IM-0864-1001.dcm.png
#   inflating: images/images_normalized/2278_IM-0864-2001.dcm.png
#   inflating: images/images_normalized/2279_IM-0865-2001.dcm.png
#   inflating: images/images_normalized/2279_IM-0865-3001.dcm.png
#   inflating: images/images_normalized/227_IM-0859-1001.dcm.png
#   inflating: images/images_normalized/227_IM-0859-12012.dcm.png
#   inflating: images/images_normalized/227_IM-0859-4004.dcm.png
#   inflating: images/images_normalized/2280_IM-0867-1001-0001.dcm.png
#   inflating: images/images_normalized/2280_IM-0867-1001-0002.dcm.png
#   inflating: images/images_normalized/2280_IM-0867-1001-0003.dcm.png
#   inflating: images/images_normalized/2280_IM-0867-2001.dcm.png
#   inflating: images/images_normalized/2281_IM-0868-2001.dcm.png
#   inflating: images/images_normalized/2282_IM-0869-1001.dcm.png
#   inflating: images/images_normalized/2282_IM-0869-2001.dcm.png
#   inflating: images/images_normalized/2283_IM-0870-1001.dcm.png
#   inflating: images/images_normalized/2283_IM-0870-2001.dcm.png
#   inflating: images/images_normalized/2285_IM-0870-1001.dcm.png
#   inflating: images/images_normalized/2285_IM-0870-2001.dcm.png
#   inflating: images/images_normalized/2286_IM-0871-1001.dcm.png
#   inflating: images/images_normalized/2286_IM-0871-2001.dcm.png
#   inflating: images/images_normalized/2287_IM-0872-1001.dcm.png
#   inflating: images/images_normalized/2287_IM-0872-2001.dcm.png
#   inflating: images/images_normalized/2288_IM-0872-1001.dcm.png
#   inflating: images/images_normalized/2288_IM-0872-1002.dcm.png
#   inflating: images/images_normalized/2289_IM-0873-1001.dcm.png
#   inflating: images/images_normalized/2289_IM-0873-2001.dcm.png
#   inflating: images/images_normalized/228_IM-0866-3001.dcm.png
#   inflating: images/images_normalized/228_IM-0866-5001.dcm.png
#   inflating: images/images_normalized/2290_IM-0874-1001.dcm.png
#   inflating: images/images_normalized/2290_IM-0874-4001.dcm.png
#   inflating: images/images_normalized/2291_IM-0874-1001.dcm.png
#   inflating: images/images_normalized/2291_IM-0874-2001.dcm.png
#   inflating: images/images_normalized/2292_IM-0874-1001.dcm.png
#   inflating: images/images_normalized/2292_IM-0874-1002.dcm.png
#   inflating: images/images_normalized/2293_IM-0875-1001.dcm.png
#   inflating: images/images_normalized/2293_IM-0875-2001.dcm.png
#   inflating: images/images_normalized/2294_IM-0876-1001.dcm.png
#   inflating: images/images_normalized/2294_IM-0876-2001.dcm.png
#   inflating: images/images_normalized/2295_IM-0876-1001.dcm.png
#   inflating: images/images_normalized/2295_IM-0876-2001.dcm.png
#   inflating: images/images_normalized/2296_IM-0876-1001.dcm.png
#   inflating: images/images_normalized/2296_IM-0876-2001.dcm.png
#   inflating: images/images_normalized/2297_IM-0877-1001.dcm.png
#   inflating: images/images_normalized/2297_IM-0877-2001.dcm.png
#   inflating: images/images_normalized/2298_IM-0878-2001.dcm.png
#   inflating: images/images_normalized/2299_IM-0878-1001.dcm.png
#   inflating: images/images_normalized/2299_IM-0878-2001.dcm.png
#   inflating: images/images_normalized/229_IM-0873-1001.dcm.png
#   inflating: images/images_normalized/229_IM-0873-2001.dcm.png
#   inflating: images/images_normalized/22_IM-0810-1001.dcm.png
#   inflating: images/images_normalized/22_IM-0810-2001.dcm.png
#   inflating: images/images_normalized/2300_IM-0881-1001.dcm.png
#   inflating: images/images_normalized/2300_IM-0881-2001.dcm.png
#   inflating: images/images_normalized/2301_IM-0881-1001.dcm.png
#   inflating: images/images_normalized/2301_IM-0881-2001.dcm.png
#   inflating: images/images_normalized/2302_IM-0882-1001.dcm.png
#   inflating: images/images_normalized/2303_IM-0882-1001.dcm.png
#   inflating: images/images_normalized/2303_IM-0882-2001.dcm.png
#   inflating: images/images_normalized/2304_IM-0882-1001.dcm.png
#   inflating: images/images_normalized/2304_IM-0882-4004.dcm.png
#   inflating: images/images_normalized/2305_IM-0882-1001.dcm.png
#   inflating: images/images_normalized/2305_IM-0882-1002.dcm.png
#   inflating: images/images_normalized/2306_IM-0882-1001.dcm.png
#   inflating: images/images_normalized/2306_IM-0882-2001.dcm.png
#   inflating: images/images_normalized/2307_IM-0882-1001.dcm.png
#   inflating: images/images_normalized/2307_IM-0882-2001.dcm.png
#   inflating: images/images_normalized/2308_IM-0883-1001.dcm.png
#   inflating: images/images_normalized/2308_IM-0883-2001.dcm.png
#   inflating: images/images_normalized/2308_IM-0883-3001.dcm.png
#   inflating: images/images_normalized/230_IM-0880-0001-0001.dcm.png
#   inflating: images/images_normalized/230_IM-0880-0001-0002.dcm.png
#   inflating: images/images_normalized/2310_IM-0885-1001.dcm.png
#   inflating: images/images_normalized/2310_IM-0885-2001.dcm.png
#   inflating: images/images_normalized/2311_IM-0886-1001.dcm.png
#   inflating: images/images_normalized/2311_IM-0886-2001.dcm.png
#   inflating: images/images_normalized/2312_IM-0887-1001.dcm.png
#   inflating: images/images_normalized/2312_IM-0887-2001.dcm.png
#   inflating: images/images_normalized/2313_IM-0888-1002001.dcm.png
#   inflating: images/images_normalized/2313_IM-0888-1004003.dcm.png
#   inflating: images/images_normalized/2314_IM-0889-1001.dcm.png
#   inflating: images/images_normalized/2314_IM-0889-2001.dcm.png
#   inflating: images/images_normalized/2315_IM-0889-1002.dcm.png
#   inflating: images/images_normalized/2315_IM-0889-1003.dcm.png
#   inflating: images/images_normalized/2316_IM-0889-1001.dcm.png
#   inflating: images/images_normalized/2316_IM-0889-2001.dcm.png
#   inflating: images/images_normalized/2317_IM-0890-1001.dcm.png
#   inflating: images/images_normalized/2317_IM-0890-2001.dcm.png
#   inflating: images/images_normalized/2318_IM-0891-1001.dcm.png
#   inflating: images/images_normalized/2318_IM-0891-2001.dcm.png
#   inflating: images/images_normalized/2319_IM-0892-2002.dcm.png
#   inflating: images/images_normalized/2319_IM-0892-3003.dcm.png
#   inflating: images/images_normalized/2320_IM-0894-1001.dcm.png
#   inflating: images/images_normalized/2320_IM-0894-2001.dcm.png
#   inflating: images/images_normalized/2321_IM-0894-1001.dcm.png
#   inflating: images/images_normalized/2321_IM-0894-2001.dcm.png
#   inflating: images/images_normalized/2321_IM-0894-3001.dcm.png
#   inflating: images/images_normalized/2322_IM-0894-1001.dcm.png
#   inflating: images/images_normalized/2322_IM-0894-1002.dcm.png
#   inflating: images/images_normalized/2323_IM-0895-12012.dcm.png
#   inflating: images/images_normalized/2323_IM-0895-2001.dcm.png
#   inflating: images/images_normalized/2324_IM-0895-1001.dcm.png
#   inflating: images/images_normalized/2324_IM-0895-2001.dcm.png
#   inflating: images/images_normalized/2325_IM-0896-1001.dcm.png
#   inflating: images/images_normalized/2325_IM-0896-2001.dcm.png
#   inflating: images/images_normalized/2326_IM-0897-1001.dcm.png
#   inflating: images/images_normalized/2326_IM-0897-2001.dcm.png
#   inflating: images/images_normalized/2327_IM-0898-1001.dcm.png
#   inflating: images/images_normalized/2327_IM-0898-2001.dcm.png
#   inflating: images/images_normalized/2328_IM-0898-1001.dcm.png
#   inflating: images/images_normalized/2328_IM-0898-2001.dcm.png
#   inflating: images/images_normalized/2329_IM-0898-2001.dcm.png
#   inflating: images/images_normalized/2330_IM-0900-2001.dcm.png
#   inflating: images/images_normalized/2331_IM-0900-1001.dcm.png
#   inflating: images/images_normalized/2332_IM-0900-1001.dcm.png
#   inflating: images/images_normalized/2332_IM-0900-1002.dcm.png
#   inflating: images/images_normalized/2333_IM-0901-2001.dcm.png
#   inflating: images/images_normalized/2334_IM-0902-1001.dcm.png
#   inflating: images/images_normalized/2334_IM-0902-1002.dcm.png
#   inflating: images/images_normalized/2335_IM-0902-1001.dcm.png
#   inflating: images/images_normalized/2335_IM-0902-2001.dcm.png
#   inflating: images/images_normalized/2336_IM-0903-1001.dcm.png
#   inflating: images/images_normalized/2336_IM-0903-2001.dcm.png
#   inflating: images/images_normalized/2336_IM-0903-3001.dcm.png
#   inflating: images/images_normalized/2337_IM-0904-2001.dcm.png
#   inflating: images/images_normalized/2338_IM-0905-1001.dcm.png
#   inflating: images/images_normalized/2338_IM-0905-2001.dcm.png
#   inflating: images/images_normalized/2338_IM-0905-3001.dcm.png
#   inflating: images/images_normalized/2339_IM-0905-1001.dcm.png
#   inflating: images/images_normalized/233_IM-0899-1001.dcm.png
#   inflating: images/images_normalized/233_IM-0899-2001.dcm.png
#   inflating: images/images_normalized/233_IM-0899-3001.dcm.png
#   inflating: images/images_normalized/2340_IM-0907-1001.dcm.png
#   inflating: images/images_normalized/2340_IM-0907-2001.dcm.png
#   inflating: images/images_normalized/2341_IM-0907-1001.dcm.png
#   inflating: images/images_normalized/2341_IM-0907-2001.dcm.png
#   inflating: images/images_normalized/2342_IM-0907-1001.dcm.png
#   inflating: images/images_normalized/2342_IM-0907-2001.dcm.png
#   inflating: images/images_normalized/2343_IM-0908-1001.dcm.png
#   inflating: images/images_normalized/2343_IM-0908-2001.dcm.png
#   inflating: images/images_normalized/2344_IM-0909-1001.dcm.png
#   inflating: images/images_normalized/2344_IM-0909-2001.dcm.png
#   inflating: images/images_normalized/2345_IM-0910-1001.dcm.png
#   inflating: images/images_normalized/2345_IM-0910-2001.dcm.png
#   inflating: images/images_normalized/2347_IM-0912-1001.dcm.png
#   inflating: images/images_normalized/2348_IM-0913-1001.dcm.png
#   inflating: images/images_normalized/2348_IM-0913-2001.dcm.png
#   inflating: images/images_normalized/2349_IM-0914-1001.dcm.png
#   inflating: images/images_normalized/2349_IM-0914-2001.dcm.png
#   inflating: images/images_normalized/234_IM-0906-0001-0001.dcm.png
#   inflating: images/images_normalized/234_IM-0906-0001-0002.dcm.png
#   inflating: images/images_normalized/2350_IM-0916-1001.dcm.png
#   inflating: images/images_normalized/2350_IM-0916-2001.dcm.png
#   inflating: images/images_normalized/2351_IM-0917-1001.dcm.png
#   inflating: images/images_normalized/2351_IM-0917-3001.dcm.png
#   inflating: images/images_normalized/2352_IM-0918-1002.dcm.png
#   inflating: images/images_normalized/2353_IM-0918-1001.dcm.png
#   inflating: images/images_normalized/2353_IM-0918-2001.dcm.png
#   inflating: images/images_normalized/2354_IM-0918-1001.dcm.png
#   inflating: images/images_normalized/2354_IM-0918-2001.dcm.png
#   inflating: images/images_normalized/2355_IM-0919-1001.dcm.png
#   inflating: images/images_normalized/2355_IM-0919-2001.dcm.png
#   inflating: images/images_normalized/2356_IM-0920-1001.dcm.png
#   inflating: images/images_normalized/2356_IM-0920-2001.dcm.png
#   inflating: images/images_normalized/2357_IM-0921-1001.dcm.png
#   inflating: images/images_normalized/2357_IM-0921-2001.dcm.png
#   inflating: images/images_normalized/2358_IM-0922-0001-0001.dcm.png
#   inflating: images/images_normalized/2358_IM-0922-0001-0002.dcm.png
#   inflating: images/images_normalized/2359_IM-0923-2001.dcm.png
#   inflating: images/images_normalized/235_IM-0915-2001.dcm.png
#   inflating: images/images_normalized/2360_IM-0925-1001.dcm.png
#   inflating: images/images_normalized/2360_IM-0925-2001.dcm.png
#   inflating: images/images_normalized/2361_IM-0926-1001.dcm.png
#   inflating: images/images_normalized/2361_IM-0926-1002.dcm.png
#   inflating: images/images_normalized/2362_IM-0926-1001.dcm.png
#   inflating: images/images_normalized/2362_IM-0926-1002.dcm.png
#   inflating: images/images_normalized/2363_IM-0926-1001.dcm.png
#   inflating: images/images_normalized/2363_IM-0926-2001.dcm.png
#   inflating: images/images_normalized/2364_IM-0927-1001.dcm.png
#   inflating: images/images_normalized/2364_IM-0927-3001.dcm.png
#   inflating: images/images_normalized/2365_IM-0927-2001.dcm.png
#   inflating: images/images_normalized/2365_IM-0927-3001.dcm.png
#   inflating: images/images_normalized/2366_IM-0928-1001.dcm.png
#   inflating: images/images_normalized/2366_IM-0928-2001.dcm.png
#   inflating: images/images_normalized/2367_IM-0928-1001.dcm.png
#   inflating: images/images_normalized/2368_IM-0928-1001.dcm.png
#   inflating: images/images_normalized/2368_IM-0928-2001.dcm.png
#   inflating: images/images_normalized/2369_IM-0929-2001.dcm.png
#   inflating: images/images_normalized/236_IM-0924-1001.dcm.png
#   inflating: images/images_normalized/236_IM-0924-1002.dcm.png
#   inflating: images/images_normalized/2370_IM-0931-1001.dcm.png
#   inflating: images/images_normalized/2370_IM-0931-2001.dcm.png
#   inflating: images/images_normalized/2371_IM-0932-1001.dcm.png
#   inflating: images/images_normalized/2371_IM-0932-2001.dcm.png
#   inflating: images/images_normalized/2372_IM-0933-0001-0001.dcm.png
#   inflating: images/images_normalized/2372_IM-0933-0001-0002.dcm.png
#   inflating: images/images_normalized/2373_IM-0934-1001.dcm.png
#   inflating: images/images_normalized/2374_IM-0935-84550001.dcm.png
#   inflating: images/images_normalized/2374_IM-0935-84550002.dcm.png
#   inflating: images/images_normalized/2375_IM-0936-1001.dcm.png
#   inflating: images/images_normalized/2375_IM-0936-2001.dcm.png
#   inflating: images/images_normalized/2376_IM-0936-1001.dcm.png
#   inflating: images/images_normalized/2376_IM-0936-2001.dcm.png
#   inflating: images/images_normalized/2377_IM-0937-1001.dcm.png
#   inflating: images/images_normalized/2377_IM-0937-3003.dcm.png
#   inflating: images/images_normalized/2378_IM-0938-1001.dcm.png
#   inflating: images/images_normalized/2378_IM-0938-1002.dcm.png
#   inflating: images/images_normalized/2379_IM-0939-1001.dcm.png
#   inflating: images/images_normalized/2379_IM-0939-2001.dcm.png
#   inflating: images/images_normalized/237_IM-0930-1001.dcm.png
#   inflating: images/images_normalized/237_IM-0930-2001.dcm.png
#   inflating: images/images_normalized/2380_IM-0940-1001.dcm.png
#   inflating: images/images_normalized/2380_IM-0940-3003.dcm.png
#   inflating: images/images_normalized/2381_IM-0941-1001.dcm.png
#   inflating: images/images_normalized/2381_IM-0941-2001.dcm.png
#   inflating: images/images_normalized/2382_IM-0941-1001.dcm.png
#   inflating: images/images_normalized/2382_IM-0941-2001.dcm.png
#   inflating: images/images_normalized/2383_IM-0941-1001.dcm.png
#   inflating: images/images_normalized/2383_IM-0941-2001.dcm.png
#   inflating: images/images_normalized/2384_IM-0942-1001.dcm.png
#   inflating: images/images_normalized/2384_IM-0942-3001.dcm.png
#   inflating: images/images_normalized/2385_IM-0942-1001.dcm.png
#   inflating: images/images_normalized/2385_IM-0942-1002.dcm.png
#   inflating: images/images_normalized/2386_IM-0942-1001.dcm.png
#   inflating: images/images_normalized/2386_IM-0942-1002.dcm.png
#   inflating: images/images_normalized/2387_IM-0943-1001.dcm.png
#   inflating: images/images_normalized/2387_IM-0943-2001.dcm.png
#   inflating: images/images_normalized/2388_IM-0944-1001.dcm.png
#   inflating: images/images_normalized/2389_IM-0944-1001.dcm.png
#   inflating: images/images_normalized/2389_IM-0944-3001.dcm.png
#   inflating: images/images_normalized/238_IM-0939-1001.dcm.png
#   inflating: images/images_normalized/238_IM-0939-2001.dcm.png
#   inflating: images/images_normalized/2390_IM-0944-1001.dcm.png
#   inflating: images/images_normalized/2390_IM-0944-1002.dcm.png
#   inflating: images/images_normalized/2391_IM-0944-1001.dcm.png
#   inflating: images/images_normalized/2391_IM-0944-2001.dcm.png
#   inflating: images/images_normalized/2392_IM-0944-1001.dcm.png
#   inflating: images/images_normalized/2393_IM-0944-1001.dcm.png
#   inflating: images/images_normalized/2393_IM-0944-2001.dcm.png
#   inflating: images/images_normalized/2394_IM-0944-1001.dcm.png
#   inflating: images/images_normalized/2394_IM-0944-2001.dcm.png
#   inflating: images/images_normalized/2395_IM-0944-1001.dcm.png
#   inflating: images/images_normalized/2395_IM-0944-2001.dcm.png
#   inflating: images/images_normalized/2396_IM-0945-1001.dcm.png
#   inflating: images/images_normalized/2396_IM-0945-2001.dcm.png
#   inflating: images/images_normalized/2397_IM-0946-1001.dcm.png
#   inflating: images/images_normalized/2397_IM-0946-2001.dcm.png
#   inflating: images/images_normalized/2397_IM-0946-3001.dcm.png
#   inflating: images/images_normalized/2398_IM-0947-12012.dcm.png
#   inflating: images/images_normalized/2398_IM-0947-2001.dcm.png
#   inflating: images/images_normalized/2398_IM-0947-4004.dcm.png
#   inflating: images/images_normalized/239_IM-0944-1001.dcm.png
#   inflating: images/images_normalized/239_IM-0944-1002.dcm.png
#   inflating: images/images_normalized/23_IM-0879-1001.dcm.png
#   inflating: images/images_normalized/23_IM-0879-2001.dcm.png
#   inflating: images/images_normalized/2400_IM-0950-1001.dcm.png
#   inflating: images/images_normalized/2400_IM-0950-1002.dcm.png
#   inflating: images/images_normalized/2401_IM-0950-1001.dcm.png
#   inflating: images/images_normalized/2401_IM-0950-2001.dcm.png
#   inflating: images/images_normalized/2402_IM-0951-1001.dcm.png
#   inflating: images/images_normalized/2402_IM-0951-2001.dcm.png
#   inflating: images/images_normalized/2403_IM-0951-1001.dcm.png
#   inflating: images/images_normalized/2403_IM-0951-2001.dcm.png
#   inflating: images/images_normalized/2404_IM-0952-1001.dcm.png
#   inflating: images/images_normalized/2404_IM-0952-2001.dcm.png
#   inflating: images/images_normalized/2405_IM-0953-1001.dcm.png
#   inflating: images/images_normalized/2405_IM-0953-2001.dcm.png
#   inflating: images/images_normalized/2406_IM-0954-1001.dcm.png
#   inflating: images/images_normalized/2406_IM-0954-1002.dcm.png
#   inflating: images/images_normalized/2407_IM-0954-1001.dcm.png
#   inflating: images/images_normalized/2407_IM-0954-2001.dcm.png
#   inflating: images/images_normalized/2408_IM-0955-2001.dcm.png
#   inflating: images/images_normalized/2408_IM-0955-4004.dcm.png
#   inflating: images/images_normalized/2409_IM-0955-1001.dcm.png
#   inflating: images/images_normalized/240_IM-0950-1001.dcm.png
#   inflating: images/images_normalized/2410_IM-0956-1001.dcm.png
#   inflating: images/images_normalized/2410_IM-0956-1002.dcm.png
#   inflating: images/images_normalized/2411_IM-0957-0001-0001.dcm.png
#   inflating: images/images_normalized/2411_IM-0957-0001-0002.dcm.png
#   inflating: images/images_normalized/2412_IM-0958-1001.dcm.png
#   inflating: images/images_normalized/2412_IM-0958-3003.dcm.png
#   inflating: images/images_normalized/2413_IM-0959-1001.dcm.png
#   inflating: images/images_normalized/2413_IM-0959-2001.dcm.png
#   inflating: images/images_normalized/2414_IM-0960-3001.dcm.png
#   inflating: images/images_normalized/2415_IM-0961-1001.dcm.png
#   inflating: images/images_normalized/2415_IM-0961-2001.dcm.png
#   inflating: images/images_normalized/2416_IM-0961-1001.dcm.png
#   inflating: images/images_normalized/2416_IM-0961-1002.dcm.png
#   inflating: images/images_normalized/2417_IM-0961-1001.dcm.png
#   inflating: images/images_normalized/2417_IM-0961-2001.dcm.png
#   inflating: images/images_normalized/2418_IM-0962-5001.dcm.png
#   inflating: images/images_normalized/2419_IM-0963-1001.dcm.png
#   inflating: images/images_normalized/2419_IM-0963-2001.dcm.png
#   inflating: images/images_normalized/241_IM-0955-1001.dcm.png
#   inflating: images/images_normalized/2420_IM-0964-0001-0001.dcm.png
#   inflating: images/images_normalized/2420_IM-0964-0001-0002.dcm.png
#   inflating: images/images_normalized/2421_IM-0965-2001.dcm.png
#   inflating: images/images_normalized/2422_IM-0965-1001.dcm.png
#   inflating: images/images_normalized/2422_IM-0965-2001.dcm.png
#   inflating: images/images_normalized/2423_IM-0965-1001.dcm.png
#   inflating: images/images_normalized/2423_IM-0965-2001.dcm.png
#   inflating: images/images_normalized/2424_IM-0966-1001.dcm.png
#   inflating: images/images_normalized/2424_IM-0966-2001.dcm.png
#   inflating: images/images_normalized/2425_IM-0967-1001.dcm.png
#   inflating: images/images_normalized/2425_IM-0967-2001.dcm.png
#   inflating: images/images_normalized/2425_IM-0967-3001.dcm.png
#   inflating: images/images_normalized/2426_IM-0968-2001.dcm.png
#   inflating: images/images_normalized/2427_IM-0969-4001.dcm.png
#   inflating: images/images_normalized/2427_IM-0969-5001.dcm.png
#   inflating: images/images_normalized/2428_IM-0970-1001.dcm.png
#   inflating: images/images_normalized/2428_IM-0970-3001.dcm.png
#   inflating: images/images_normalized/242_IM-0963-1001.dcm.png
#   inflating: images/images_normalized/242_IM-0963-2001.dcm.png
#   inflating: images/images_normalized/2430_IM-0972-3001.dcm.png
#   inflating: images/images_normalized/2431_IM-0973-1001.dcm.png
#   inflating: images/images_normalized/2431_IM-0973-2001.dcm.png
#   inflating: images/images_normalized/2432_IM-0974-1001.dcm.png
#   inflating: images/images_normalized/2432_IM-0974-4001.dcm.png
#   inflating: images/images_normalized/2433_IM-0975-1001.dcm.png
#   inflating: images/images_normalized/2433_IM-0975-2001.dcm.png
#   inflating: images/images_normalized/2433_IM-0975-3001.dcm.png
#   inflating: images/images_normalized/2434_IM-0976-1001.dcm.png
#   inflating: images/images_normalized/2434_IM-0976-1002.dcm.png
#   inflating: images/images_normalized/2435_IM-0976-1001.dcm.png
#   inflating: images/images_normalized/2435_IM-0976-2001.dcm.png
#   inflating: images/images_normalized/2436_IM-0976-1001.dcm.png
#   inflating: images/images_normalized/2436_IM-0976-2001.dcm.png
#   inflating: images/images_normalized/2437_IM-0977-2002.dcm.png
#   inflating: images/images_normalized/2437_IM-0977-3003.dcm.png
#   inflating: images/images_normalized/2438_IM-0978-1001.dcm.png
#   inflating: images/images_normalized/2438_IM-0978-4004.dcm.png
#   inflating: images/images_normalized/2439_IM-0978-1001.dcm.png
#   inflating: images/images_normalized/2439_IM-0978-2001.dcm.png
#   inflating: images/images_normalized/243_IM-0971-2001.dcm.png
#   inflating: images/images_normalized/2440_IM-0978-1001.dcm.png
#   inflating: images/images_normalized/2440_IM-0978-2001.dcm.png
#   inflating: images/images_normalized/2441_IM-0978-1001.dcm.png
#   inflating: images/images_normalized/2441_IM-0978-2001.dcm.png
#   inflating: images/images_normalized/2442_IM-0979-1001.dcm.png
#   inflating: images/images_normalized/2442_IM-0979-2001.dcm.png
#   inflating: images/images_normalized/2443_IM-0980-1001.dcm.png
#   inflating: images/images_normalized/2443_IM-0980-2001.dcm.png
#   inflating: images/images_normalized/2444_IM-0980-1001.dcm.png
#   inflating: images/images_normalized/2444_IM-0980-2001.dcm.png
#   inflating: images/images_normalized/2445_IM-0981-2002.dcm.png
#   inflating: images/images_normalized/2445_IM-0981-3003.dcm.png
#   inflating: images/images_normalized/2446_IM-0982-1001.dcm.png
#   inflating: images/images_normalized/2446_IM-0982-2001.dcm.png
#   inflating: images/images_normalized/2447_IM-0983-1001.dcm.png
#   inflating: images/images_normalized/2447_IM-0983-2001.dcm.png
#   inflating: images/images_normalized/2448_IM-0983-1001.dcm.png
#   inflating: images/images_normalized/2448_IM-0983-2001.dcm.png
#   inflating: images/images_normalized/2449_IM-0984-1001.dcm.png
#   inflating: images/images_normalized/2449_IM-0984-2001.dcm.png
#   inflating: images/images_normalized/244_IM-0978-1001.dcm.png
#   inflating: images/images_normalized/2450_IM-0986-1001.dcm.png
#   inflating: images/images_normalized/2450_IM-0986-2001.dcm.png
#   inflating: images/images_normalized/2451_IM-0987-1001.dcm.png
#   inflating: images/images_normalized/2451_IM-0987-1002.dcm.png
#   inflating: images/images_normalized/2453_IM-0988-1001.dcm.png
#   inflating: images/images_normalized/2453_IM-0988-2001.dcm.png
#   inflating: images/images_normalized/2454_IM-0989-1001.dcm.png
#   inflating: images/images_normalized/2454_IM-0989-1002.dcm.png
#   inflating: images/images_normalized/2455_IM-0989-1001.dcm.png
#   inflating: images/images_normalized/2455_IM-0989-2001.dcm.png
#   inflating: images/images_normalized/2456_IM-0989-1001.dcm.png
#   inflating: images/images_normalized/2456_IM-0989-2001.dcm.png
#   inflating: images/images_normalized/2457_IM-0989-1001.dcm.png
#   inflating: images/images_normalized/2457_IM-0989-2001.dcm.png
#   inflating: images/images_normalized/2458_IM-0990-1001.dcm.png
#   inflating: images/images_normalized/2458_IM-0990-2001.dcm.png
#   inflating: images/images_normalized/2459_IM-0991-1001.dcm.png
#   inflating: images/images_normalized/2459_IM-0991-1002.dcm.png
#   inflating: images/images_normalized/245_IM-0985-1001.dcm.png
#   inflating: images/images_normalized/245_IM-0985-2001.dcm.png
#   inflating: images/images_normalized/2460_IM-0993-1001.dcm.png
#   inflating: images/images_normalized/2460_IM-0993-2001.dcm.png
#   inflating: images/images_normalized/2461_IM-0994-0001-0001.dcm.png
#   inflating: images/images_normalized/2461_IM-0994-0001-0002.dcm.png
#   inflating: images/images_normalized/2462_IM-0995-1001.dcm.png
#   inflating: images/images_normalized/2462_IM-0995-3001.dcm.png
#   inflating: images/images_normalized/2463_IM-0996-1001.dcm.png
#   inflating: images/images_normalized/2463_IM-0996-2001.dcm.png
#   inflating: images/images_normalized/2464_IM-0997-1001.dcm.png
#   inflating: images/images_normalized/2464_IM-0997-2001.dcm.png
#   inflating: images/images_normalized/2465_IM-0997-1001.dcm.png
#   inflating: images/images_normalized/2465_IM-0997-2001.dcm.png
#   inflating: images/images_normalized/2466_IM-0997-1001.dcm.png
#   inflating: images/images_normalized/2466_IM-0997-1003.dcm.png
#   inflating: images/images_normalized/2467_IM-0997-1001.dcm.png
#   inflating: images/images_normalized/2467_IM-0997-2001.dcm.png
#   inflating: images/images_normalized/2468_IM-0998-1001.dcm.png
#   inflating: images/images_normalized/2468_IM-0998-2001.dcm.png
#   inflating: images/images_normalized/2469_IM-0999-1001.dcm.png
#   inflating: images/images_normalized/2469_IM-0999-3001.dcm.png
#   inflating: images/images_normalized/246_IM-0992-1002001.dcm.png
#   inflating: images/images_normalized/246_IM-0992-1003002.dcm.png
#   inflating: images/images_normalized/2470_IM-1001-1001.dcm.png
#   inflating: images/images_normalized/2470_IM-1001-2001.dcm.png
#   inflating: images/images_normalized/2470_IM-1001-3001.dcm.png
#   inflating: images/images_normalized/2471_IM-1002-1001.dcm.png
#   inflating: images/images_normalized/2471_IM-1002-1002.dcm.png
#   inflating: images/images_normalized/2472_IM-1002-2001.dcm.png
#   inflating: images/images_normalized/2473_IM-1003-1001.dcm.png
#   inflating: images/images_normalized/2473_IM-1003-2001.dcm.png
#   inflating: images/images_normalized/2474_IM-1003-1001.dcm.png
#   inflating: images/images_normalized/2475_IM-1004-1001.dcm.png
#   inflating: images/images_normalized/2475_IM-1004-2001.dcm.png
#   inflating: images/images_normalized/2476_IM-1005-1001.dcm.png
#   inflating: images/images_normalized/2476_IM-1005-2001.dcm.png
#   inflating: images/images_normalized/2477_IM-1006-1001.dcm.png
#   inflating: images/images_normalized/2477_IM-1006-1002.dcm.png
#   inflating: images/images_normalized/2478_IM-1007-1001.dcm.png
#   inflating: images/images_normalized/2478_IM-1007-2001.dcm.png
#   inflating: images/images_normalized/2479_IM-1007-2001.dcm.png
#   inflating: images/images_normalized/247_IM-1000-1001.dcm.png
#   inflating: images/images_normalized/247_IM-1000-2001.dcm.png
#   inflating: images/images_normalized/2480_IM-1009-1001.dcm.png
#   inflating: images/images_normalized/2480_IM-1009-2001.dcm.png
#   inflating: images/images_normalized/2481_IM-1010-12012.dcm.png
#   inflating: images/images_normalized/2482_IM-1011-0001-0001.dcm.png
#   inflating: images/images_normalized/2482_IM-1011-0001-0002.dcm.png
#   inflating: images/images_normalized/2483_IM-1012-1001.dcm.png
#   inflating: images/images_normalized/2483_IM-1012-2001.dcm.png
#   inflating: images/images_normalized/2484_IM-1012-1001.dcm.png
#   inflating: images/images_normalized/2484_IM-1012-2001.dcm.png
#   inflating: images/images_normalized/2485_IM-1013-1001.dcm.png
#   inflating: images/images_normalized/2485_IM-1013-2001.dcm.png
#   inflating: images/images_normalized/2486_IM-1014-1001.dcm.png
#   inflating: images/images_normalized/2486_IM-1014-2001.dcm.png
#   inflating: images/images_normalized/2487_IM-1014-1001.dcm.png
#   inflating: images/images_normalized/2487_IM-1014-2001.dcm.png
#   inflating: images/images_normalized/2488_IM-1015-1001.dcm.png
#   inflating: images/images_normalized/2489_IM-1016-1001.dcm.png
#   inflating: images/images_normalized/2489_IM-1016-2001.dcm.png
#   inflating: images/images_normalized/248_IM-1008-85149002.dcm.png
#   inflating: images/images_normalized/248_IM-1008-85149003.dcm.png
#   inflating: images/images_normalized/2490_IM-1017-1001.dcm.png
#   inflating: images/images_normalized/2490_IM-1017-2001.dcm.png
#   inflating: images/images_normalized/2491_IM-1017-1001.dcm.png
#   inflating: images/images_normalized/2491_IM-1017-2001.dcm.png
#   inflating: images/images_normalized/2492_IM-1018-1001.dcm.png
#   inflating: images/images_normalized/2492_IM-1018-2001.dcm.png
#   inflating: images/images_normalized/2493_IM-1019-4001.dcm.png
#   inflating: images/images_normalized/2493_IM-1019-8001.dcm.png
#   inflating: images/images_normalized/2494_IM-1020-1001.dcm.png
#   inflating: images/images_normalized/2494_IM-1020-2001.dcm.png
#   inflating: images/images_normalized/2495_IM-1021-1001.dcm.png
#   inflating: images/images_normalized/2495_IM-1021-2001.dcm.png
#   inflating: images/images_normalized/2496_IM-1022-2001.dcm.png
#   inflating: images/images_normalized/2497_IM-1022-1001.dcm.png
#   inflating: images/images_normalized/2497_IM-1022-3003.dcm.png
#   inflating: images/images_normalized/2498_IM-1022-1001.dcm.png
#   inflating: images/images_normalized/2498_IM-1022-2001.dcm.png
#   inflating: images/images_normalized/2499_IM-1023-1001.dcm.png
#   inflating: images/images_normalized/2499_IM-1023-2001.dcm.png
#   inflating: images/images_normalized/249_IM-1016-1001.dcm.png
#   inflating: images/images_normalized/249_IM-1016-2001.dcm.png
#   inflating: images/images_normalized/24_IM-0949-1001.dcm.png
#   inflating: images/images_normalized/24_IM-0949-2001.dcm.png
#   inflating: images/images_normalized/2501_IM-1027-1001.dcm.png
#   inflating: images/images_normalized/2501_IM-1027-2001.dcm.png
#   inflating: images/images_normalized/2502_IM-1027-1001-0001.dcm.png
#   inflating: images/images_normalized/2502_IM-1027-1001-0002.dcm.png
#   inflating: images/images_normalized/2503_IM-1028-1001.dcm.png
#   inflating: images/images_normalized/2503_IM-1028-2001.dcm.png
#   inflating: images/images_normalized/2504_IM-1029-1001.dcm.png
#   inflating: images/images_normalized/2504_IM-1029-2001.dcm.png
#   inflating: images/images_normalized/2505_IM-1029-1001.dcm.png
#   inflating: images/images_normalized/2505_IM-1029-2001.dcm.png
#   inflating: images/images_normalized/2506_IM-1029-1001.dcm.png
#   inflating: images/images_normalized/2506_IM-1029-2001.dcm.png
#   inflating: images/images_normalized/2507_IM-1030-2001.dcm.png
#   inflating: images/images_normalized/2507_IM-1030-3001.dcm.png
#   inflating: images/images_normalized/2509_IM-1031-1001.dcm.png
#   inflating: images/images_normalized/2509_IM-1031-2001.dcm.png
#   inflating: images/images_normalized/250_IM-1025-1001.dcm.png
#   inflating: images/images_normalized/250_IM-1025-2001.dcm.png
#   inflating: images/images_normalized/2510_IM-1033-1001.dcm.png
#   inflating: images/images_normalized/2510_IM-1033-2001.dcm.png
#   inflating: images/images_normalized/2511_IM-1034-1001.dcm.png
#   inflating: images/images_normalized/2511_IM-1034-2001.dcm.png
#   inflating: images/images_normalized/2512_IM-1034-1001.dcm.png
#   inflating: images/images_normalized/2513_IM-1035-1001.dcm.png
#   inflating: images/images_normalized/2514_IM-1036-1001.dcm.png
#   inflating: images/images_normalized/2514_IM-1036-2001.dcm.png
#   inflating: images/images_normalized/2515_IM-1036-1001.dcm.png
#   inflating: images/images_normalized/2516_IM-1036-1001.dcm.png
#   inflating: images/images_normalized/2516_IM-1036-2001.dcm.png
#   inflating: images/images_normalized/2517_IM-1036-1001.dcm.png
#   inflating: images/images_normalized/2517_IM-1036-2001.dcm.png
#   inflating: images/images_normalized/2518_IM-1036-1001.dcm.png
#   inflating: images/images_normalized/2518_IM-1036-2001.dcm.png
#   inflating: images/images_normalized/2519_IM-1037-1001.dcm.png
#   inflating: images/images_normalized/2519_IM-1037-2001.dcm.png
#   inflating: images/images_normalized/251_IM-1032-1001.dcm.png
#   inflating: images/images_normalized/251_IM-1032-3001.dcm.png
#   inflating: images/images_normalized/251_IM-1032-4001.dcm.png
#   inflating: images/images_normalized/2520_IM-1039-27001.dcm.png
#   inflating: images/images_normalized/2520_IM-1039-28001.dcm.png
#   inflating: images/images_normalized/2522_IM-1040-1001.dcm.png
#   inflating: images/images_normalized/2523_IM-1041-1001.dcm.png
#   inflating: images/images_normalized/2523_IM-1041-2001.dcm.png
#   inflating: images/images_normalized/2524_IM-1042-1001.dcm.png
#   inflating: images/images_normalized/2524_IM-1042-2001.dcm.png
#   inflating: images/images_normalized/2525_IM-1043-2001.dcm.png
#   inflating: images/images_normalized/2526_IM-1043-1001.dcm.png
#   inflating: images/images_normalized/2526_IM-1043-2001.dcm.png
#   inflating: images/images_normalized/2527_IM-1043-1001.dcm.png
#   inflating: images/images_normalized/2527_IM-1043-2001.dcm.png
#   inflating: images/images_normalized/2528_IM-1044-1001.dcm.png
#   inflating: images/images_normalized/2528_IM-1044-2001.dcm.png
#   inflating: images/images_normalized/2529_IM-1044-1001.dcm.png
#   inflating: images/images_normalized/2529_IM-1044-2001.dcm.png
#   inflating: images/images_normalized/252_IM-1038-1001.dcm.png
#   inflating: images/images_normalized/252_IM-1038-2001.dcm.png
#   inflating: images/images_normalized/2530_IM-1045-1001.dcm.png
#   inflating: images/images_normalized/2531_IM-1045-1001.dcm.png
#   inflating: images/images_normalized/2531_IM-1045-2001.dcm.png
#   inflating: images/images_normalized/2532_IM-1046-1001.dcm.png
#   inflating: images/images_normalized/2532_IM-1046-2001.dcm.png
#   inflating: images/images_normalized/2533_IM-1047-1001.dcm.png
#   inflating: images/images_normalized/2533_IM-1047-2001.dcm.png
#   inflating: images/images_normalized/2535_IM-1048-1002.dcm.png
#   inflating: images/images_normalized/2536_IM-1049-1001.dcm.png
#   inflating: images/images_normalized/2536_IM-1049-2001.dcm.png
#   inflating: images/images_normalized/2537_IM-1049-1001.dcm.png
#   inflating: images/images_normalized/2537_IM-1049-2001.dcm.png
#   inflating: images/images_normalized/2538_IM-1050-1001.dcm.png
#   inflating: images/images_normalized/2538_IM-1050-1002.dcm.png
#   inflating: images/images_normalized/2539_IM-1050-1001.dcm.png
#   inflating: images/images_normalized/2539_IM-1050-2001.dcm.png
#   inflating: images/images_normalized/2539_IM-1050-3001.dcm.png
#   inflating: images/images_normalized/253_IM-1045-1001.dcm.png
#   inflating: images/images_normalized/253_IM-1045-2001.dcm.png
#   inflating: images/images_normalized/2540_IM-1052-1001.dcm.png
#   inflating: images/images_normalized/2540_IM-1052-2001.dcm.png
#   inflating: images/images_normalized/2541_IM-1053-2001.dcm.png
#   inflating: images/images_normalized/2541_IM-1053-3001.dcm.png
#   inflating: images/images_normalized/2542_IM-1053-1001.dcm.png
#   inflating: images/images_normalized/2542_IM-1053-2001.dcm.png
#   inflating: images/images_normalized/2543_IM-1054-1001.dcm.png
#   inflating: images/images_normalized/2543_IM-1054-2001.dcm.png
#   inflating: images/images_normalized/2543_IM-1054-3001.dcm.png
#   inflating: images/images_normalized/2544_IM-1054-1001.dcm.png
#   inflating: images/images_normalized/2544_IM-1054-2001.dcm.png
#   inflating: images/images_normalized/2545_IM-1054-1001.dcm.png
#   inflating: images/images_normalized/2545_IM-1054-1002.dcm.png
#   inflating: images/images_normalized/2546_IM-1055-1001.dcm.png
#   inflating: images/images_normalized/2546_IM-1055-2001.dcm.png
#   inflating: images/images_normalized/2547_IM-1055-4004.dcm.png
#   inflating: images/images_normalized/2548_IM-1056-0001-0001.dcm.png
#   inflating: images/images_normalized/2548_IM-1056-0001-0002.dcm.png
#   inflating: images/images_normalized/2549_IM-1057-1001.dcm.png
#   inflating: images/images_normalized/2549_IM-1057-2001.dcm.png
# ...
#   inflating: images/images_normalized/886_IM-2400-1001.dcm.png
#   inflating: images/images_normalized/886_IM-2400-1002.dcm.png
#   inflating: images/images_normalized/887_IM-2400-1001.dcm.png
#   inflating: images/images_normalized/887_IM-2400-2001.dcm.png
#   inflating: images/images_normalized/888_IM-2401-1001.dcm.png
#   inflating: images/images_normalized/888_IM-2401-2001.dcm.png
#   inflating: images/images_normalized/889_IM-2401-1001.dcm.png
#   inflating: images/images_normalized/889_IM-2401-2001.dcm.png
#   inflating: images/images_normalized/88_IM-2394-2001.dcm.png
#   inflating: images/images_normalized/890_IM-2403-1001.dcm.png
#   inflating: images/images_normalized/890_IM-2403-2001.dcm.png
#   inflating: images/images_normalized/891_IM-2403-1001.dcm.png
#   inflating: images/images_normalized/891_IM-2403-2001.dcm.png
#   inflating: images/images_normalized/892_IM-2403-1001.dcm.png
#   inflating: images/images_normalized/892_IM-2403-2001.dcm.png
#   inflating: images/images_normalized/893_IM-2403-1001.dcm.png
#   inflating: images/images_normalized/893_IM-2403-2001.dcm.png
#   inflating: images/images_normalized/894_IM-2404-0001-0001.dcm.png
#   inflating: images/images_normalized/894_IM-2404-0001-0002.dcm.png
#   inflating: images/images_normalized/896_IM-2406-1001.dcm.png
#   inflating: images/images_normalized/896_IM-2406-2001.dcm.png
#   inflating: images/images_normalized/896_IM-2406-3001.dcm.png
#   inflating: images/images_normalized/897_IM-2406-1001.dcm.png
#   inflating: images/images_normalized/897_IM-2406-2001.dcm.png
#   inflating: images/images_normalized/899_IM-2407-1001.dcm.png
#   inflating: images/images_normalized/899_IM-2407-2001.dcm.png
#   inflating: images/images_normalized/89_IM-2402-1001.dcm.png
#   inflating: images/images_normalized/89_IM-2402-2001.dcm.png
#   inflating: images/images_normalized/8_IM-2333-1001.dcm.png
#   inflating: images/images_normalized/8_IM-2333-2001.dcm.png
#   inflating: images/images_normalized/900_IM-2408-2001.dcm.png
#   inflating: images/images_normalized/901_IM-2409-1001.dcm.png
#   inflating: images/images_normalized/901_IM-2409-2001.dcm.png
#   inflating: images/images_normalized/901_IM-2409-3001.dcm.png
#   inflating: images/images_normalized/902_IM-2409-1001.dcm.png
#   inflating: images/images_normalized/902_IM-2409-2001.dcm.png
#   inflating: images/images_normalized/903_IM-2409-1001.dcm.png
#   inflating: images/images_normalized/903_IM-2409-1002.dcm.png
#   inflating: images/images_normalized/904_IM-2409-3003.dcm.png
#   inflating: images/images_normalized/905_IM-2410-0001-0001.dcm.png
#   inflating: images/images_normalized/905_IM-2410-0001-0002.dcm.png
#   inflating: images/images_normalized/906_IM-2411-1001.dcm.png
#   inflating: images/images_normalized/906_IM-2411-2001.dcm.png
#   inflating: images/images_normalized/907_IM-2412-82526002.dcm.png
#   inflating: images/images_normalized/907_IM-2412-82526003.dcm.png
#   inflating: images/images_normalized/908_IM-2413-1001.dcm.png
#   inflating: images/images_normalized/908_IM-2413-3001.dcm.png
#   inflating: images/images_normalized/909_IM-2414-1001.dcm.png
#   inflating: images/images_normalized/909_IM-2414-1002.dcm.png
#   inflating: images/images_normalized/90_IM-2407-1001.dcm.png
#   inflating: images/images_normalized/90_IM-2407-2001.dcm.png
#   inflating: images/images_normalized/910_IM-2416-1001.dcm.png
#   inflating: images/images_normalized/910_IM-2416-2001.dcm.png
#   inflating: images/images_normalized/911_IM-2417-1001.dcm.png
#   inflating: images/images_normalized/911_IM-2417-1002.dcm.png
#   inflating: images/images_normalized/912_IM-2417-1001.dcm.png
#   inflating: images/images_normalized/912_IM-2417-2001.dcm.png
#   inflating: images/images_normalized/913_IM-2417-1001.dcm.png
#   inflating: images/images_normalized/913_IM-2417-2001.dcm.png
#   inflating: images/images_normalized/914_IM-2417-1001.dcm.png
#   inflating: images/images_normalized/914_IM-2417-3001.dcm.png
#   inflating: images/images_normalized/915_IM-2418-2002.dcm.png
#   inflating: images/images_normalized/915_IM-2418-3003.dcm.png
#   inflating: images/images_normalized/916_IM-2419-1001.dcm.png
#   inflating: images/images_normalized/916_IM-2419-2001.dcm.png
#   inflating: images/images_normalized/917_IM-2419-1001.dcm.png
#   inflating: images/images_normalized/917_IM-2419-2001.dcm.png
#   inflating: images/images_normalized/918_IM-2420-4001.dcm.png
#   inflating: images/images_normalized/918_IM-2420-4004.dcm.png
#   inflating: images/images_normalized/919_IM-2421-1001.dcm.png
#   inflating: images/images_normalized/919_IM-2421-2001.dcm.png
#   inflating: images/images_normalized/91_IM-2415-2001.dcm.png
#   inflating: images/images_normalized/920_IM-2423-1001.dcm.png
#   inflating: images/images_normalized/920_IM-2423-1002.dcm.png
#   inflating: images/images_normalized/921_IM-2423-1001.dcm.png
#   inflating: images/images_normalized/921_IM-2423-2001.dcm.png
#   inflating: images/images_normalized/922_IM-2423-1001.dcm.png
#   inflating: images/images_normalized/922_IM-2423-2001.dcm.png
#   inflating: images/images_normalized/923_IM-2424-2001.dcm.png
#   inflating: images/images_normalized/923_IM-2424-3001.dcm.png
#   inflating: images/images_normalized/925_IM-2425-1001.dcm.png
#   inflating: images/images_normalized/925_IM-2425-2001.dcm.png
#   inflating: images/images_normalized/926_IM-2425-1001.dcm.png
#   inflating: images/images_normalized/926_IM-2425-2001.dcm.png
#   inflating: images/images_normalized/927_IM-2425-1001.dcm.png
#   inflating: images/images_normalized/927_IM-2425-2001.dcm.png
#   inflating: images/images_normalized/928_IM-2426-1001.dcm.png
#   inflating: images/images_normalized/928_IM-2426-2002.dcm.png
#   inflating: images/images_normalized/929_IM-2427-1001.dcm.png
#   inflating: images/images_normalized/929_IM-2427-2001.dcm.png
#   inflating: images/images_normalized/92_IM-2422-1001.dcm.png
#   inflating: images/images_normalized/92_IM-2422-4004.dcm.png
#   inflating: images/images_normalized/930_IM-2429-1001.dcm.png
#   inflating: images/images_normalized/930_IM-2429-2001.dcm.png
#   inflating: images/images_normalized/930_IM-2429-3001.dcm.png
#   inflating: images/images_normalized/931_IM-2429-1001.dcm.png
#   inflating: images/images_normalized/931_IM-2429-2001.dcm.png
#   inflating: images/images_normalized/932_IM-2430-2001.dcm.png
#   inflating: images/images_normalized/932_IM-2430-3001.dcm.png
#   inflating: images/images_normalized/932_IM-2430-4004.dcm.png
#   inflating: images/images_normalized/933_IM-2431-1001.dcm.png
#   inflating: images/images_normalized/933_IM-2431-1002.dcm.png
#   inflating: images/images_normalized/934_IM-2432-1001.dcm.png
#   inflating: images/images_normalized/934_IM-2432-2001.dcm.png
#   inflating: images/images_normalized/935_IM-2432-1001.dcm.png
#   inflating: images/images_normalized/935_IM-2432-2001.dcm.png
#   inflating: images/images_normalized/936_IM-2432-1001.dcm.png
#   inflating: images/images_normalized/937_IM-2433-1001.dcm.png
#   inflating: images/images_normalized/937_IM-2433-2001.dcm.png
#   inflating: images/images_normalized/938_IM-2434-1001.dcm.png
#   inflating: images/images_normalized/938_IM-2434-2001.dcm.png
#   inflating: images/images_normalized/939_IM-2435-1001.dcm.png
#   inflating: images/images_normalized/939_IM-2435-2001.dcm.png
#   inflating: images/images_normalized/93_IM-2428-1001.dcm.png
#   inflating: images/images_normalized/93_IM-2428-2001.dcm.png
#   inflating: images/images_normalized/940_IM-2437-2001.dcm.png
#   inflating: images/images_normalized/940_IM-2437-3001.dcm.png
#   inflating: images/images_normalized/941_IM-2438-1001.dcm.png
#   inflating: images/images_normalized/941_IM-2438-2001.dcm.png
#   inflating: images/images_normalized/942_IM-2438-1001.dcm.png
#   inflating: images/images_normalized/942_IM-2438-2001.dcm.png
#   inflating: images/images_normalized/943_IM-2439-3003.dcm.png
#   inflating: images/images_normalized/943_IM-2439-5005.dcm.png
#   inflating: images/images_normalized/944_IM-2440-1001.dcm.png
#   inflating: images/images_normalized/944_IM-2440-2001.dcm.png
#   inflating: images/images_normalized/945_IM-2440-1001.dcm.png
#   inflating: images/images_normalized/945_IM-2440-2001.dcm.png
#   inflating: images/images_normalized/946_IM-2441-1001.dcm.png
#   inflating: images/images_normalized/946_IM-2441-2001.dcm.png
#   inflating: images/images_normalized/947_IM-2442-1001.dcm.png
#   inflating: images/images_normalized/947_IM-2442-2001.dcm.png
#   inflating: images/images_normalized/948_IM-2443-1001.dcm.png
#   inflating: images/images_normalized/948_IM-2443-2001.dcm.png
#   inflating: images/images_normalized/949_IM-2444-1001.dcm.png
#   inflating: images/images_normalized/94_IM-2436-1001.dcm.png
#   inflating: images/images_normalized/94_IM-2436-2001.dcm.png
#   inflating: images/images_normalized/950_IM-2446-1003002.dcm.png
#   inflating: images/images_normalized/950_IM-2446-1004003.dcm.png
#   inflating: images/images_normalized/951_IM-2447-1001.dcm.png
#   inflating: images/images_normalized/951_IM-2447-2001.dcm.png
#   inflating: images/images_normalized/952_IM-2447-2002.dcm.png
#   inflating: images/images_normalized/952_IM-2447-3003.dcm.png
#   inflating: images/images_normalized/953_IM-2447-1001.dcm.png
#   inflating: images/images_normalized/954_IM-2448-12001.dcm.png
#   inflating: images/images_normalized/955_IM-2449-1001.dcm.png
#   inflating: images/images_normalized/955_IM-2449-2001.dcm.png
#   inflating: images/images_normalized/956_IM-2449-1001.dcm.png
#   inflating: images/images_normalized/957_IM-2449-1001.dcm.png
#   inflating: images/images_normalized/957_IM-2449-2001.dcm.png
#   inflating: images/images_normalized/958_IM-2449-1001.dcm.png
#   inflating: images/images_normalized/958_IM-2449-1002.dcm.png
#   inflating: images/images_normalized/959_IM-2449-1001.dcm.png
#   inflating: images/images_normalized/959_IM-2449-2001.dcm.png
#   inflating: images/images_normalized/95_IM-2445-1001.dcm.png
#   inflating: images/images_normalized/95_IM-2445-1002.dcm.png
#   inflating: images/images_normalized/960_IM-2451-11001.dcm.png
#   inflating: images/images_normalized/960_IM-2451-4004.dcm.png
#   inflating: images/images_normalized/961_IM-2452-84646001.dcm.png
#   inflating: images/images_normalized/961_IM-2452-84646002.dcm.png
#   inflating: images/images_normalized/962_IM-2453-1002001.dcm.png
#   inflating: images/images_normalized/962_IM-2453-1003002.dcm.png
#   inflating: images/images_normalized/963_IM-2454-1001.dcm.png
#   inflating: images/images_normalized/963_IM-2454-2001.dcm.png
#   inflating: images/images_normalized/964_IM-2454-1001.dcm.png
#   inflating: images/images_normalized/964_IM-2454-1002.dcm.png
#   inflating: images/images_normalized/965_IM-2455-1001.dcm.png
#   inflating: images/images_normalized/965_IM-2455-2001.dcm.png
#   inflating: images/images_normalized/966_IM-2456-1001.dcm.png
#   inflating: images/images_normalized/966_IM-2456-2001.dcm.png
#   inflating: images/images_normalized/967_IM-2457-2002.dcm.png
#   inflating: images/images_normalized/967_IM-2457-3003.dcm.png
#   inflating: images/images_normalized/968_IM-2458-1001.dcm.png
#   inflating: images/images_normalized/968_IM-2458-2001.dcm.png
#   inflating: images/images_normalized/969_IM-2459-1001.dcm.png
#   inflating: images/images_normalized/969_IM-2459-2001.dcm.png
#   inflating: images/images_normalized/96_IM-2450-2002.dcm.png
#   inflating: images/images_normalized/96_IM-2450-3003.dcm.png
#   inflating: images/images_normalized/970_IM-2460-2001.dcm.png
#   inflating: images/images_normalized/970_IM-2460-3001.dcm.png
#   inflating: images/images_normalized/971_IM-2461-1001.dcm.png
#   inflating: images/images_normalized/971_IM-2461-2001.dcm.png
#   inflating: images/images_normalized/972_IM-2461-1001-0001.dcm.png
#   inflating: images/images_normalized/972_IM-2461-1001-0002.dcm.png
#   inflating: images/images_normalized/973_IM-2462-1001.dcm.png
#   inflating: images/images_normalized/973_IM-2462-2001.dcm.png
#   inflating: images/images_normalized/974_IM-2463-1001.dcm.png
#   inflating: images/images_normalized/974_IM-2463-2001.dcm.png
#   inflating: images/images_normalized/974_IM-2463-3001.dcm.png
#   inflating: images/images_normalized/975_IM-2464-1001.dcm.png
#   inflating: images/images_normalized/975_IM-2464-2001.dcm.png
#   inflating: images/images_normalized/976_IM-2464-1001.dcm.png
#   inflating: images/images_normalized/976_IM-2464-2001.dcm.png
#   inflating: images/images_normalized/977_IM-2465-1001.dcm.png
#   inflating: images/images_normalized/977_IM-2465-2001.dcm.png
#   inflating: images/images_normalized/978_IM-2465-2001.dcm.png
#   inflating: images/images_normalized/979_IM-2466-1001.dcm.png
#   inflating: images/images_normalized/979_IM-2466-2001.dcm.png
#   inflating: images/images_normalized/97_IM-2460-1001.dcm.png
#   inflating: images/images_normalized/97_IM-2460-3003.dcm.png
#   inflating: images/images_normalized/980_IM-2468-1001.dcm.png
#   inflating: images/images_normalized/980_IM-2468-2001.dcm.png
#   inflating: images/images_normalized/981_IM-2469-1001.dcm.png
#   inflating: images/images_normalized/982_IM-2470-1001.dcm.png
#   inflating: images/images_normalized/982_IM-2470-3003.dcm.png
#   inflating: images/images_normalized/983_IM-2471-1001.dcm.png
#   inflating: images/images_normalized/983_IM-2471-2001.dcm.png
#   inflating: images/images_normalized/984_IM-2471-1001.dcm.png
#   inflating: images/images_normalized/984_IM-2471-2001.dcm.png
#   inflating: images/images_normalized/984_IM-2471-3001.dcm.png
#   inflating: images/images_normalized/985_IM-2472-1001.dcm.png
#   inflating: images/images_normalized/986_IM-2473-2002.dcm.png
#   inflating: images/images_normalized/986_IM-2473-3003.dcm.png
#   inflating: images/images_normalized/987_IM-2474-1001.dcm.png
#   inflating: images/images_normalized/988_IM-2474-1001.dcm.png
#   inflating: images/images_normalized/988_IM-2474-2001.dcm.png
#   inflating: images/images_normalized/989_IM-2475-1002001.dcm.png
#   inflating: images/images_normalized/989_IM-2475-1003002.dcm.png
#   inflating: images/images_normalized/98_IM-2467-1001.dcm.png
#   inflating: images/images_normalized/98_IM-2467-4004.dcm.png
#   inflating: images/images_normalized/990_IM-2476-1001.dcm.png
#   inflating: images/images_normalized/990_IM-2476-2001.dcm.png
#   inflating: images/images_normalized/991_IM-2476-1001.dcm.png
#   inflating: images/images_normalized/991_IM-2476-2001.dcm.png
#   inflating: images/images_normalized/992_IM-2477-0001-0001.dcm.png
#   inflating: images/images_normalized/992_IM-2477-0001-0002.dcm.png
#   inflating: images/images_normalized/993_IM-2478-1001.dcm.png
#   inflating: images/images_normalized/993_IM-2478-1002.dcm.png
#   inflating: images/images_normalized/994_IM-2478-1001.dcm.png
#   inflating: images/images_normalized/994_IM-2478-2001.dcm.png
#   inflating: images/images_normalized/995_IM-2478-1001.dcm.png
#   inflating: images/images_normalized/995_IM-2478-1002.dcm.png
#   inflating: images/images_normalized/996_IM-2479-1001.dcm.png
#   inflating: images/images_normalized/996_IM-2479-2001.dcm.png
#   inflating: images/images_normalized/997_IM-2479-1001.dcm.png
#   inflating: images/images_normalized/997_IM-2479-2001.dcm.png
#   inflating: images/images_normalized/998_IM-2479-1001.dcm.png
#   inflating: images/images_normalized/998_IM-2479-2001.dcm.png
#   inflating: images/images_normalized/999_IM-2480-1001.dcm.png
#   inflating: images/images_normalized/999_IM-2480-2001.dcm.png
#   inflating: images/images_normalized/999_IM-2480-3001.dcm.png
#   inflating: images/images_normalized/99_IM-2476-1001.dcm.png
#   inflating: images/images_normalized/99_IM-2476-1002.dcm.png
#   inflating: images/images_normalized/9_IM-2407-1001.dcm.png
#   inflating: images/images_normalized/9_IM-2407-2001.dcm.png
#   inflating: indiana_projections.csv
#   inflating: indiana_reports.csv

# %%
# !git clone https://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@github.com/falco-tigris/CS577_DeepLearning_Project.git
# Out:
# Cloning into 'CS577_DeepLearning_Project'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 66 (delta 22), reused 55 (delta 15), pack-reused 0
# Receiving objects: 100% (66/66), 457.27 KiB | 9.94 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# !cp -r /content/CS577_DeepLearning_Project/* /content/

# %%
# !cp /content/indiana_projections.csv /content/data
# !cp /content/indiana_reports.csv /content/data
# !cp -r /content/images /content/data

# %% [markdown]
# # Pretrained CNN + Transformer decoder

# %%
import math
import torch
import numpy as np
from tqdm import tqdm
import torch.nn as nn
from torch.nn import functional as F
from torchtext.data.metrics import bleu_score
from torch.utils.data.dataloader import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class ImageEncoderReportDecoderConfig:

    def __init__(self, vocab_size, block_size, n_embd, pretrain, train_decoder, pretrained_encoder_model):
        self.vocab_size = vocab_size
        self.block_size = block_size
        self.n_embd = n_embd
        self.pretrain = pretrain
        self.train_decoder = train_decoder
        self.pretrained_encoder_model = pretrained_encoder_model

class ImageEncoderReportDecoder(nn.Module):

    def __init__(self, config, img_enc, img_enc_out_shape, img_enc_name="ResNet18"):
        super().__init__()

        self.cnf = config
        self.img_enc_name = img_enc_name

        self.img_enc = img_enc
        self.img_enc_linear = nn.Linear(img_enc_out_shape[1], config.n_embd)

        self.pos_emb = nn.Parameter(torch.zeros(1, config.block_size, config.n_embd))
        self.drop = nn.Dropout(0.3)

        encoder_layer = nn.TransformerEncoderLayer(d_model=config.n_embd, nhead=33, dim_feedforward=2048, dropout=0.3, activation='gelu', batch_first=True, norm_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=1)


        self.contrastive_head = nn.Linear(config.n_embd, 1)

        self.tgt_emb = nn.Embedding(config.vocab_size, config.n_embd)
        self.tgt_drop = nn.Dropout(0.3)

        decoder_layer = nn.TransformerDecoderLayer(d_model=config.n_embd, nhead=33, dim_feedforward=2048, dropout=0.3, activation='gelu', batch_first=True, norm_first=True)
        self.transformer_decoder = nn.TransformerDecoder(decoder_layer, num_layers=2)

        self.dcd_proj = nn.Linear(config.n_embd, config.vocab_size)

        self.block_size = config.block_size
        self.apply(self._init_weights)

        self.register_buffer("mask", torch.triu(torch.ones(config.block_size, config.block_size)*float('-inf'),diagonal=1))
        self.mask = self.mask < 0

    def get_block_size(self):
        return self.block_size

    def _init_weights(self, module):
        if isinstance(module, (nn.Linear, nn.Embedding)):
            module.weight.data.normal_(mean=0.0, std=0.02)
            if isinstance(module, nn.Linear) and module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def forward(self, x, targets, len_mask):

        loss = None
        logit = None
        prediction = None


        reps = self.representation(x)
        logit, loss, prediction = self.decode(reps, targets, len_mask)

        return logit, loss, prediction

    def configure_optimizers(self, train_config):

        optimizer = torch.optim.AdamW(self.parameters(), lr=train_config.learning_rate, betas=train_config.betas)
        return optimizer

    def get_block_size(self):
        return self.block_size

    def representation(self, x):
        x_org = x

        if self.img_enc_name == "ResNet18" or self.img_enc_name == "UNet":
            x = torch.cat((x.unsqueeze(1),x.unsqueeze(1),x.unsqueeze(1)), dim=1)
            x_org = x_org.unsqueeze(1)
        elif self.img_enc_name == "ResNetAE":
            x = x.unsqueeze(1)

        with torch.no_grad():
            x = self.img_enc(x)
            if self.img_enc_name == "ResNetAE":
                b,t,e1,e2 = x['z'].shape
                x = x['z'].reshape((b,t,-1))
            elif self.img_enc_name == "UNet":
                pass

        if len(x.shape) < 3:
            x = x.unsqueeze(2)
        elif len(x.shape) > 3:
            x = x.squeeze(1)

        x = self.img_enc_linear(x)
        b, t, _ = x.size()
        x = x + self.pos_emb[:, :t,:]
        x = self.drop(x)
        reps = self.transformer_encoder(x)

        return reps

    def decode(self, reps, targets, len_mask=None):

        tgt_emb = self.tgt_emb(targets)
        _, tt, _ = tgt_emb.size()
        tgt_emb = tgt_emb + self.pos_emb[:, :tt, :]
        tgt_emb = self.tgt_drop(tgt_emb)

        if len_mask != None:
            len_mask = len_mask > 0
            dec_out = self.transformer_decoder(tgt_emb[:,:-1,:], reps, tgt_mask=self.mask[:-1,:-1], tgt_key_padding_mask=len_mask[:,:-1])
        else:
            dec_out = self.transformer_decoder(tgt_emb, reps)

        logits = self.dcd_proj(dec_out)
        loss = 0
        if len_mask != None:
            loss += F.cross_entropy(logits.view(-1,logits.shape[-1]), targets[:,1:].reshape(-1), reduction='none')

        prediction = torch.argmax(logits,dim=-1)
        return logits, loss, prediction

class TrainerConfig:
    # optimization parameters
    max_epochs = 10
    batch_size = 64
    learning_rate = 3e-4
    betas = (0.9, 0.95)
    grad_norm_clip = 1.0
    weight_decay = 0.1 # only applied on matmul weights
    # learning rate decay params: linear warmup followed by cosine decay to 10% of original
    lr_decay = False
    warmup_tokens = 375e6 # these two numbers come from the GPT-3 paper, but may not be good defaults elsewhere
    final_tokens = 260e9 # (at what point we reach 10% of original LR)

    # checkpoint settings
    ckpt_path = None
    num_workers = 0 # for DataLoader
    pretrain = False
    tokenizer = None

    def __init__(self, **kwargs):
        for k,v in kwargs.items():
            setattr(self, k, v)

class Trainer:

    def __init__(self, model, train_dataset, test_dataset, config, word_2_id, id_2_word):
        self.model = model
        self.config = config
        self.train_dataset = train_dataset
        self.test_dataset = test_dataset
        self.id_2_word = id_2_word
        self.word_2_id = word_2_id
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def save_checkpoint(self):
        # DataParallel wrappers keep raw model object in .module attribute
        raw_model = self.model.module if hasattr(self.model, "module") else self.model
        torch.save(raw_model.state_dict(), self.config.ckpt_path)

    def train(self):
        model, config = self.model, self.config
        raw_model = model.module if hasattr(self.model, "module") else model
        optimizer = raw_model.configure_optimizers(config)

        def run_epoch(split):
            is_train = split == 'train'
            model.train(is_train)
            data = self.train_dataset if is_train else self.test_dataset
            loader = DataLoader(data, shuffle=True, pin_memory=True,
                                batch_size=config.batch_size,
                                num_workers=config.num_workers)

            losses = []
            tgts = []
            preds = []
            pbar = tqdm(enumerate(loader), total=len(loader)) if is_train else enumerate(loader)
            for it, (x, y, len_masks) in pbar:

                # place data on the correct device
                x = x.to(self.device)
                y = y.to(self.device)
                len_masks = len_masks.to(self.device)

                # forward the model
                with torch.set_grad_enabled(is_train):
                    _, loss, pred = model(x, y, len_masks)
                    loss = loss.mean()
                    losses.append(loss.item())
                    tgts.append(y)
                    preds.append(pred)

                if is_train:
                    # backprop and update the parameters
                    model.zero_grad()
                    loss.backward()
                    torch.nn.utils.clip_grad_norm_(model.parameters(), config.grad_norm_clip)
                    optimizer.step()

                    # decay the learning rate based on our progress
                    if config.lr_decay:
                        self.tokens += (y >= 0).sum() # number of tokens processed this step (i.e. label is not -100)
                        if self.tokens < config.warmup_tokens:
                            # linear warmup
                            lr_mult = float(self.tokens) / float(max(1, config.warmup_tokens))
                        else:
                            # cosine learning rate decay
                            progress = float(self.tokens - config.warmup_tokens) / float(max(1, config.final_tokens - config.warmup_tokens))
                            lr_mult = max(0.1, 0.5 * (1.0 + math.cos(math.pi * progress)))
                        lr = config.learning_rate * lr_mult
                        for param_group in optimizer.param_groups:
                            param_group['lr'] = lr
                    else:
                        lr = config.learning_rate

                    # report progress
                    pbar.set_description(f"epoch {epoch+1} iter {it}: train loss {loss.item():.5f}. lr {lr:e}")

            if not is_train:
                test_loss = float(np.mean(losses))

                test_bleu = 0
                if not config.pretrain:
                    tgts = torch.vstack(tgts).cpu().numpy().tolist()
                    preds = torch.vstack(preds).cpu().numpy().tolist()
                    tgts_list = []
                    preds_list = []
                    for i in range(len(tgts)):
                        try:
                            eos_ind = tgts[i].index(self.tokenizer.eos_token)
                        except:
                            eos_ind = len(tgts[i])-1


                        tgts_list.append(tgts[i][:eos_ind])
                        tgts_list[-1] = [[self.id_2_word[x] for x in tgts_list[-1]]]

                    for i in range(len(preds)):
                        try:
                            eos_ind = preds[i].index(self.tokenizer.eos_token)
                        except:
                            eos_ind = len(preds[i])-1

                        preds_list.append(preds[i][:eos_ind])
                        preds_list[-1] = [str(self.id_2_word[x]) for x in preds_list[-1]]

                    assert(len(preds_list) == len(tgts_list))

                    test_bleu = bleu_score(preds_list, tgts_list, max_n=4, weights=[0.5, 0.5, 0, 0])
                    print("bleu_score_2: ", test_bleu)

                print("test loss: ", test_loss)

                return test_loss, test_bleu

            return float(np.mean(losses)), None

        best_loss = float('inf')
        best_bleu = float('-inf')

        self.tokens = 0

        for epoch in range(config.max_epochs):

            train_loss, _ = run_epoch('train')
            if self.test_dataset is not None:
                test_loss, test_bleu = run_epoch('test')

            print("Train: ", train_loss, "Test: ", test_loss)

            # supports early stopping based on the test loss, or just save always if no test set is provided
            good_model = self.test_dataset is None or test_loss < 1.05*best_loss or test_bleu > best_bleu
            if self.config.ckpt_path is not None and good_model:
                if test_loss < best_loss:
                    best_loss = test_loss
                if test_bleu > best_bleu:
                    best_bleu = test_bleu
                self.save_checkpoint()

# %% [markdown]
# ## Data

# %%
import torch
import numpy as np
import pandas as pd
from utils import set_seed
import models.training as tr
import data.preprocessing as pr
from torchvision import transforms
from matplotlib import pyplot as plt
from tokenizer.tokenizer import Tokenizer
from collections import OrderedDict

#########################
set_seed(33)
#use model as densenet121 for densenet
# Pretrained CNN models
img_enc_resnet = torch.hub.load('pytorch/vision:v0.8.0', 'resnet18', pretrained=False)

#uncomment the below lines for densenet
# state_dict = torch.load('/content/m-30012020-104001.pth.tar')
# new_state_dict = OrderedDict()
# for k, v in state_dict.items():
#     if 'denseblock' in k:
#         param = k.split(".")
#         k = ".".join(param[:-3] + [param[-3]+param[-2]] + [param[-1]])
#         new_state_dict[k] = v
# img_enc_resnet.load_state_dict(new_state_dict,strict=False)
# img_enc_resnet.classifier = torch.nn.Linear(1024, 512)
img_enc_resnet.fc = torch.nn.Identity()

img_enc_resnet.input_shape = (224, 224)
img_enc_resnet.output_shape = (512, 1)

img_enc_name =  "rnet"
img_enc = img_enc_resnet
img_enc_width, img_enc_height = img_enc.input_shape
img_enc_out_shape = img_enc.output_shape
block_size = 512
##########################
reports = pr.load_reports()
tokenizer = Tokenizer(reports, 'word')

# Load data
batch_size = 8
# Load data
uids = np.unique(pr.projections.index)

# Image preprocessing
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((224, 224), antialias=False)
])

train_data, val_data, test_data = pr.create_dataloaders(uids, pr.IMAGES_PATH, max_length=block_size, batch_size=batch_size, transform=transform, tokenizer=tokenizer)
# train_data, train_loader, val_data, val_loader, test_data, test_loader = pr.create_dataloaders(uids, pr.IMAGES_PATH, max_length=block_size, batch_size=batch_size, transform=transform, tokenizer=tokenizer)
# print(f'There are {len(train_data) :,} samples for training, and {len(val_data) :,} samples for validation testing')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.8.0
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# Create model
vocab_size = tokenizer.get_vocab_size()
n_embd = 528
config = ImageEncoderReportDecoderConfig(vocab_size, block_size, n_embd, True, True, None)
model = ImageEncoderReportDecoder(config, img_enc, img_enc_out_shape, img_enc_name)
model.to(device)

# Train model
epochs = 5
tokens_per_epoch = len(train_data) * block_size

train_config = TrainerConfig(max_epochs=epochs, batch_size=8, learning_rate=1.0e-3,
                          betas = (0.9, 0.95), weight_decay=0, lr_decay=True,
                          warmup_tokens=tokens_per_epoch,
                          final_tokens= epochs*tokens_per_epoch,
                          ckpt_path='reportnet',
                          num_workers=8,
                          pretrain = True)

# trainer = Trainer(model, train_data, val_data, train_config, tokenizer.word2idx, tokenizer.idx2word)
# trainer.train()

# # Save model
# torch.save(model.state_dict(), 'model.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %% [markdown]
# ## Predict

# %%
import torch

# Create model
vocab_size = tokenizer.get_vocab_size()
config = ImageEncoderReportDecoderConfig(vocab_size, block_size, 528, True, True, None)
model = ImageEncoderReportDecoder(config, img_enc, img_enc_out_shape, img_enc_name)
model.load_state_dict(torch.load('model.pth'))
# Out:
# <All keys matched successfully>

# %%
@torch.no_grad()
def sample(model, x, y0, steps):
    """
    take a conditioning sequence of indices in x (of shape (b,t)) and predict the next token in
    the sequence, feeding the predictions back into the model each time. Clearly the sampling
    has quadratic complexity unlike an RNN that is only linear, and has a finite context window
    of block_size, unlike an RNN that has an infinite context window.
    """
    model.eval()
    generated = []

    y1 = y0
    reps = model.representation(x)

    for k in range(steps):
        logits, _, _ = model.decode(reps, y0, None)
        logits = logits[:, -1, :]
        y1 = torch.argmax(logits, dim=1).unsqueeze(0)
        generated.append(y1.item())
        y0 = torch.cat((y0, y1), dim=1)

    return generated

# %%
tgts = []
preds = []

print("len val dataset:", len(val_data))
pbar = tqdm(enumerate(val_data))

for it, (x, y, mask) in pbar:
    x = x.unsqueeze(0).to("cuda")
    y = y.unsqueeze(0).unsqueeze(2).to("cuda")

    mask = mask.unsqueeze(0).to("cuda")
    gen = sample(model.to("cuda"), x, y[:, 0, :], steps=30)

    y = [item.item() for sublist in y[0] for item in sublist]
    tgts.append(torch.IntTensor(y))
    preds.append(torch.IntTensor(gen))
    # pr.print_sequence(y, tokenizer.idx2word)
    # pr.print_sequence(gen, tokenizer.idx2word)

tgts = torch.vstack(tgts).cpu().numpy().tolist()
preds = torch.vstack(preds).cpu().numpy().tolist()
tgts_list = []
preds_list = []
for i in range(len(tgts)):
    try:
        eos_ind = tgts[i].index(tokenizer.eos_token)
    except:
        eos_ind = len(tgts[i]) - 1

    tgts_list.append(tgts[i][:eos_ind])
    tgts_list[-1] = [[tokenizer.idx2word[x] for x in tgts_list[-1]]]

for i in range(len(preds)):
    try:
        eos_ind = preds[i].index(tokenizer.eos_token)
    except:
        eos_ind = len(preds[i]) - 1

    preds_list.append(preds[i][:eos_ind])
    # preds_list[-1] = tokenizer.decode(preds_list[-1]).split()
    preds_list[-1] = [str(tokenizer.idx2word[x]) for x in preds_list[-1]]

test_bleu_1 = bleu_score(preds_list, tgts_list, max_n=4, weights=[1, 0, 0, 0])
test_bleu_2 = bleu_score(preds_list, tgts_list, max_n=4, weights=[0.5, 0.5, 0, 0])
test_bleu_3 = bleu_score(preds_list, tgts_list, max_n=4, weights=[0.34, 0.33, 0.33, 0])
test_bleu_4 = bleu_score(preds_list, tgts_list, max_n=4, weights=[0.25, 0.25, 0.25, 0.25])
avg_bleu = (test_bleu_1 + test_bleu_2 + test_bleu_3 + test_bleu_4) / 4
print(f"\nBleu Scores:\nB_1:{test_bleu_1} \nB_2:{test_bleu_2} \nB_3:{test_bleu_3} \nB_4:{test_bleu_4}\n----Avg:{avg_bleu} ----")
# Out:
# len val dataset: 1495
# 1495it [04:59,  5.00it/s]
# Bleu Scores:
# B_1:0.17196721770476692
# B_2:0.10390777126579594
# B_3:0.0741463480342335
# B_4:0.056423741096470394
# ----Avg:0.10161126952531668 ----

# %%
tgts = []
preds = []

print("len val dataset:", len(test_data))
pbar = tqdm(enumerate(test_data))

for it, (x, y, mask) in pbar:
    x = x.unsqueeze(0).to("cuda")
    y = y.unsqueeze(0).unsqueeze(2).to("cuda")

    mask = mask.unsqueeze(0).to("cuda")
    gen = sample(model.to("cuda"), x, y[:, 0, :], steps=30)

    y = [item.item() for sublist in y[0] for item in sublist]
    tgts.append(torch.IntTensor(y))
    preds.append(torch.IntTensor(gen))
    # pr.print_sequence(y, tokenizer.idx2word)
    # pr.print_sequence(gen, tokenizer.idx2word)

tgts = torch.vstack(tgts).cpu().numpy().tolist()
preds = torch.vstack(preds).cpu().numpy().tolist()
tgts_list = []
preds_list = []
for i in range(len(tgts)):
    try:
        eos_ind = tgts[i].index(tokenizer.eos_token)
    except:
        eos_ind = len(tgts[i]) - 1

    tgts_list.append(tgts[i][:eos_ind])
    tgts_list[-1] = [[tokenizer.idx2word[x] for x in tgts_list[-1]]]

for i in range(len(preds)):
    try:
        eos_ind = preds[i].index(tokenizer.eos_token)
    except:
        eos_ind = len(preds[i]) - 1

    preds_list.append(preds[i][:eos_ind])
    # preds_list[-1] = tokenizer.decode(preds_list[-1]).split()
    preds_list[-1] = [str(tokenizer.idx2word[x]) for x in preds_list[-1]]

test_bleu_1 = bleu_score(preds_list, tgts_list, max_n=4, weights=[1, 0, 0, 0])
test_bleu_2 = bleu_score(preds_list, tgts_list, max_n=4, weights=[0.5, 0.5, 0, 0])
test_bleu_3 = bleu_score(preds_list, tgts_list, max_n=4, weights=[0.34, 0.33, 0.33, 0])
test_bleu_4 = bleu_score(preds_list, tgts_list, max_n=4, weights=[0.25, 0.25, 0.25, 0.25])
avg_bleu = (test_bleu_1 + test_bleu_2 + test_bleu_3 + test_bleu_4) / 4
print(f"\nBleu Scores:\nB_1:{test_bleu_1} \nB_2:{test_bleu_2} \nB_3:{test_bleu_3} \nB_4:{test_bleu_4}\n----Avg:{avg_bleu} ----")
# Out:
# len val dataset: 1493
# 1493it [04:59,  4.98it/s]
# Bleu Scores:
# B_1:0.16962956302209464
# B_2:0.10233284128569753
# B_3:0.0730797575523815
# B_4:0.05593645047671087
# ----Avg:0.10024465308422113 ----

# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-4.7.1-py3-none-any.whl (16.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 68.5 MB/s eta 0:00:00
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.2.2)
# Collecting fastapi (from gradio)
#   Downloading fastapi-0.104.1-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 13.2 MB/s eta 0:00:00
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.7.0 (from gradio)
#   Downloading gradio_client-0.7.0-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.7/302.7 kB 38.5 MB/s eta 0:00:00
# Collecting httpx (from gradio)
#   Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.19.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.23.5)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (9.4.0)
# Collecting pydantic>=2.0 (from gradio)
#   Downloading pydantic-2.5.2-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 39.8 MB/s eta 0:00:00
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart (from gradio)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.31.0)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: typer[all]<1.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.5.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.24.0.post1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.7.0->gradio) (2023.6.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.7.0->gradio)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.14.0->gradio) (3.13.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.14.0->gradio) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Collecting annotated-types>=0.4.0 (from pydantic>=2.0->gradio)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.14.5 (from pydantic>=2.0->gradio)
#   Downloading pydantic_core-2.14.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 87.3 MB/s eta 0:00:00
# Collecting typing-extensions~=4.0 (from gradio)
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio) (2023.7.22)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio) (8.1.7)
# Collecting colorama<0.5.0,>=0.4.3 (from typer[all]<1.0,>=0.9->gradio)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting shellingham<2.0.0,>=1.3.0 (from typer[all]<1.0,>=0.9->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio) (13.7.0)
# Collecting h11>=0.8 (from uvicorn>=0.14.0->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi->gradio)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 9.5 MB/s eta 0:00:00
# Collecting httpcore==1.* (from httpx->gradio)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.13.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (0.1.2)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5579 sha256=7b23b095d24f332fe63d49d3d91b964696cf037fb353f5ce3fc36d06b4ee6c92
#   Stored in directory: /root/.cache/pip/wheels/01/a6/d1/1c0828c304a4283b2c1639a09ad86f83d7c487ef34c6b4a1bf
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, websockets, typing-extensions, tomlkit, shellingham, semantic-version, python-multipart, orjson, h11, colorama, annotated-types, aiofiles, uvicorn, starlette, pydantic-core, httpcore, pydantic, httpx, gradio-client, fastapi, gradio
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed aiofiles-23.2.1 annotated-types-0.6.0 colorama-0.4.6 fastapi-0.104.1 ffmpy-0.3.1 gradio-4.7.1 gradio-client-0.7.0 h11-0.14.0 httpcore-1.0.2 httpx-0.25.2 orjson-3.9.10 pydantic-2.5.2 pydantic-core-2.14.5 pydub-0.25.1 python-multipart-0.0.6 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.27.0 tomlkit-0.12.0 typing-extensions-4.8.0 uvicorn-0.24.0.post1 websockets-11.0.3

# %%
#restart runtime before running
import gradio as gr

# %%
from PIL import Image
import requests

# %%
import gradio as gr
import torch
from PIL import Image
import torchvision.transforms as transforms
# Import other necessary libraries and modules

# Load your model
config = ImageEncoderReportDecoderConfig(vocab_size, block_size, n_embd, True, True, None)

model = ImageEncoderReportDecoder(config, img_enc, img_enc_out_shape, img_enc_name)
model.load_state_dict(torch.load('model.pth'))
model = model.to("cuda")

from tokenizer.tokenizer import Tokenizer
import data.preprocessing as pr

# Load your reports data. This depends on how your 'pr.load_reports()' function works.
reports = pr.load_reports()

# Instantiate the tokenizer with these reports
tokenizer = Tokenizer(reports, 'word')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
@torch.no_grad()
def sample(model, x, y0, steps):
    model.eval()
    generated = []

    y1 = y0
    reps = model.representation(x)

    for k in range(steps):
        logits, _, _ = model.decode(reps, y0, None)
        logits = logits[:, -1, :]
        y1 = torch.argmax(logits, dim=1).unsqueeze(0)
        generated.append(y1.item())
        y0 = torch.cat((y0, y1), dim=1)

    return generated

# Function to generate text report
def generate_text_report(image, model, tokenizer, steps=30):
    # Image Preprocessing
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor()
    ])
    print(image)
    image = transform(image).unsqueeze(0)  # Add batch dimension

    # Initial token for generation (modify as per your model's requirement)
    initial_token = torch.tensor([tokenizer.word2idx["<SOS>"]]).unsqueeze(0)

    # Generate prediction
    gen = sample(model, image.to("cuda"), initial_token.to("cuda"), steps)

    # Convert prediction to text
    report = [tokenizer.idx2word[idx] for idx in gen if idx in tokenizer.idx2word]
    return ' '.join(report)

# Gradio interface
def gradio_interface(image):
    return generate_text_report(image, model, tokenizer)

iface = gr.Interface(
    fn=gradio_interface,
    inputs=gr.Image(type='pil'),
    outputs="text",
    title="CS577 - Deep Learning Project \n Chest X-Ray Report Generation",
    description="Upload a chest X-ray image to get a report."
)

# %%
iface.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://dfc291fbe3f9838b87.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://dfc291fbe3f9838b87.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# <PIL.Image.Image image mode=RGB size=2048x2575 at 0x7B856C3F69E0>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://dfc291fbe3f9838b87.gradio.live
